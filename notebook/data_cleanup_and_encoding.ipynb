# %% [markdown]
# # Importación de dependencias y de los archivos parquet

# %%
import pandas as pd
import dask.dataframe as dd
import numpy as np
from sklearn.preprocessing import OneHotEncoder, LabelEncoder

# %%
train_dask = dd.read_parquet('../data/raw/train')
test_dask = dd.read_parquet('../data/raw/test')
train_dataset = train_dask.compute()
test_dataset = test_dask.compute()

# %% [markdown]
# #### Limpieza de campos

# %%
train_dataset.drop(['id','url','region_url','image_url','description'],axis=1,inplace=True)
test_dataset.drop(['id','url','region_url','image_url','description'],axis=1,inplace=True)
train_dataset.baths = train_dataset.baths.astype(np.int64)
test_dataset.baths = test_dataset.baths.astype(np.int64)

# %% [markdown]
# #### Codificación de variables categoricas

# %%
oho = OneHotEncoder(dtype=np.int64,handle_unknown='ignore',sparse=False)
X = train_dataset[['laundry_options','parking_options']]
oho_df = pd.DataFrame(oho.fit_transform(X))
oho_df.index = train_dataset.index
oho_df.columns = oho.get_feature_names_out()
train_dataset.drop(['laundry_options','parking_options'], axis=1, inplace=True)
train_dataset = pd.concat([train_dataset, oho_df], axis=1)
# Out:
# c:\Users\pukeboy71\Documents\Henry-PI\New folder\predImmobiliario\venv\Lib\site-packages\sklearn\preprocessing\_encoders.py:828: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
oho = OneHotEncoder(dtype=np.int64,handle_unknown='ignore',sparse=False)
X = test_dataset[['laundry_options','parking_options']]
oho_df = pd.DataFrame(oho.fit_transform(X))
oho_df.index = test_dataset.index
oho_df.columns = oho.get_feature_names_out()
test_dataset.drop(['laundry_options','parking_options'], axis=1, inplace=True)
test_dataset = pd.concat([test_dataset, oho_df], axis=1)
# Out:
# c:\Users\pukeboy71\Documents\Henry-PI\New folder\predImmobiliario\venv\Lib\site-packages\sklearn\preprocessing\_encoders.py:828: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
le = LabelEncoder()
le_df = pd.DataFrame(le.fit_transform(train_dataset[['state']]))
le_df.columns = ['stateid']
train_dataset = pd.concat([train_dataset, le_df], axis=1)
le_df = pd.DataFrame(le.fit_transform(train_dataset[['type']]))
le_df.columns = ['typeid']
train_dataset = pd.concat([train_dataset, le_df], axis=1)
# Out:
# c:\Users\pukeboy71\Documents\Henry-PI\New folder\predImmobiliario\venv\Lib\site-packages\sklearn\preprocessing\_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\pukeboy71\Documents\Henry-PI\New folder\predImmobiliario\venv\Lib\site-packages\sklearn\preprocessing\_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
le = LabelEncoder()
le_df = pd.DataFrame(le.fit_transform(test_dataset[['state']]))
le_df.columns = ['stateid']
test_dataset = pd.concat([test_dataset, le_df], axis=1)
le_df = pd.DataFrame(le.fit_transform(test_dataset[['type']]))
le_df.columns = ['typeid']
test_dataset = pd.concat([test_dataset, le_df], axis=1)
# Out:
# c:\Users\pukeboy71\Documents\Henry-PI\New folder\predImmobiliario\venv\Lib\site-packages\sklearn\preprocessing\_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\pukeboy71\Documents\Henry-PI\New folder\predImmobiliario\venv\Lib\site-packages\sklearn\preprocessing\_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
pd.set_option('display.max_rows', 0)
pd.set_option('display.max_columns', 30)

test_dataset[test_dataset.isnull().any(axis=1)].head()
# Out:
#         region       type  sqfeet  beds  baths  cats_allowed  dogs_allowed  \
# 252     austin  apartment     428     0      1             1             1
# 320       ames  townhouse    1123     3      1             1             0
# 524     toledo  apartment    1020     2      1             0             1
# 626  knoxville  apartment     550     1      1             1             1
# 784    wichita      house    2800     3      2             1             1
#
#      smoking_allowed  wheelchair_access  electric_vehicle_charge  \
# 252                1                  0                        0
# 320                0                  0                        0
# 524                1                  0                        0
# 626                1                  0                        0
# 784                0                  0                        0
#
#      comes_furnished  lat  long state  laundry_options_laundry in bldg  \
# 252                0  NaN   NaN    tx                                1
# 320                1  NaN   NaN    ia                                0
# 524                0  NaN   NaN    oh                                0
# 626                0  NaN   NaN    tn                                0
# 784                0  NaN   NaN    ks                                0
#
#      laundry_options_laundry on site  laundry_options_no laundry on site  \
# 252                                0                                   0
# 320                                0                                   0
# 524                                0                                   0
# 626                                1                                   0
# 784                                0                                   0
#
#      laundry_options_w/d hookups  laundry_options_w/d in unit  \
# 252                            0                            0
# 320                            0                            1
# 524                            0                            0
# 626                            0                            0
# 784                            1                            0
#
#      laundry_options_None  parking_options_attached garage  \
# 252                     0                                0
# 320                     0                                0
# 524                     1                                1
# 626                     0                                0
# 784                     0                                1
#
#      parking_options_carport  parking_options_detached garage  \
# 252                        0                                1
# 320                        0                                0
# 524                        0                                0
# 626                        0                                0
# 784                        0                                0
#
#      parking_options_no parking  parking_options_off-street parking  \
# 252                           0                                   0
# 320                           0                                   1
# 524                           0                                   0
# 626                           0                                   1
# 784                           0                                   0
#
#      parking_options_street parking  parking_options_valet parking  \
# 252                               0                              0
# 320                               0                              0
# 524                               0                              0
# 626                               0                              0
# 784                               0                              0
#
#      parking_options_None  stateid  typeid
# 252                     0       43       0
# 320                     0       12       9
# 524                     0       35       0
# 626                     0       42       0
# 784                     0       16       5

# %% [markdown]
# #### Limpieza de datos

# %%
train_dataset.drop(train_dataset[train_dataset.baths > 8].index,inplace=True)
train_dataset.drop(train_dataset[(train_dataset.baths > 4) & (train_dataset.type == 'apartment')].index,inplace=True)

# %%
train_dataset.drop(train_dataset[train_dataset.beds > 8].index,inplace=True)

# %%
upperlimit = (train_dataset['sqfeet'].std() * 1.5) + train_dataset['sqfeet'].median()
train_dataset.drop(train_dataset[train_dataset.sqfeet >= upperlimit].index,inplace=True)

# %%
train_dataset.drop(train_dataset[train_dataset.lat > 100].index,inplace=True)
train_dataset.drop(train_dataset[train_dataset.lat < -15].index,inplace=True)
train_dataset.drop(train_dataset[train_dataset.long > -30].index,inplace=True)

# %%
train_dataset.reset_index(drop=True, inplace=True)

# %%
train_dataset[train_dataset.isnull().any(axis=1)].head()
# Out:
#                      region  price       type  sqfeet  beds  baths  \
# 62   worcester / central MA   1450  townhouse    1100     2      2
# 369            grand rapids   1165  apartment     892     2      1
# 501                  denver   2456  apartment     932     2      2
# 840                columbia    975  apartment     964     2      2
# 975      sarasota-bradenton   1800      house    2300     2      1
#
#      cats_allowed  dogs_allowed  smoking_allowed  wheelchair_access  \
# 62              0             0                1                  0
# 369             1             1                1                  0
# 501             1             1                0                  0
# 840             1             1                0                  1
# 975             0             0                0                  0
#
#      electric_vehicle_charge  comes_furnished  lat  long state  ...  \
# 62                         0                0  NaN   NaN    ma  ...
# 369                        0                0  NaN   NaN    mi  ...
# 501                        0                0  NaN   NaN    co  ...
# 840                        0                0  NaN   NaN    sc  ...
# 975                        0                1  NaN   NaN    fl  ...
#
#      laundry_options_laundry on site  laundry_options_no laundry on site  \
# 62                                 0                                   0
# 369                                0                                   0
# 501                                0                                   0
# 840                                0                                   0
# 975                                0                                   0
#
#      laundry_options_w/d hookups  laundry_options_w/d in unit  \
# 62                             0                            1
# 369                            1                            0
# 501                            0                            1
# 840                            0                            1
# 975                            1                            0
#
#      laundry_options_None  parking_options_attached garage  \
# 62                      0                                1
# 369                     0                                0
# 501                     0                                1
# 840                     0                                0
# 975                     0                                1
#
#      parking_options_carport  parking_options_detached garage  \
# 62                         0                                0
# 369                        0                                0
# 501                        0                                0
# 840                        0                                0
# 975                        0                                0
#
#      parking_options_no parking  parking_options_off-street parking  \
# 62                            0                                   0
# 369                           0                                   0
# 501                           0                                   0
# 840                           0                                   0
# 975                           0                                   0
#
#      parking_options_street parking  parking_options_valet parking  \
# 62                                0                              0
# 369                               0                              0
# 501                               0                              0
# 840                               0                              0
# 975                               0                              0
#
#      parking_options_None  stateid  typeid
# 62                      0       19      11
# 369                     1       22       0
# 501                     0        5       0
# 840                     1       40       0
# 975                     0        9       6
#
# [5 rows x 31 columns]

# %%
train_dask = dd.from_pandas(train_dataset,npartitions=4)
train_dask.to_parquet('../data/processed/train',name_function=lambda x: f"train-{x}.parquet")
test_dask = dd.from_pandas(test_dataset,npartitions=2)
test_dask.to_parquet('../data/processed/test',name_function=lambda x: f"test-{x}.parquet")
